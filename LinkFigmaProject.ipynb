# %% [markdown]
# <a href="https://colab.research.google.com/github/PradenaTiara/UI-UX/blob/main/LinkFigmaProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import display, HTML

figma_url = "https://www.figma.com/design/UWOPJLuKDHymUQM84gDZZl/UI-UX-APP-Kebersihan?node-id=0-1&t=XzhqWDhI1U399OH0-1"

display(HTML(f'<a href="{figma_url}" target="_blank">Buka Figma Design</a>'))
# Out:
# <a href="https://www.figma.com/design/UWOPJLuKDHymUQM84gDZZl/UI-UX-APP-Kebersihan?node-id=0-1&t=XzhqWDhI1U399OH0-1" target="_blank">Buka Figma Design</a>
